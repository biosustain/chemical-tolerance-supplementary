# %% [markdown]
# # Processing mutations

# %% [markdown]
# The variant calls from the BreSeq pipeline are parsed and analysed. All strains with _mutX_ mutations are excluded as they accumulate SNPs at a very high rate, masking interesting mutations.
#
# Mutations that are present in all strains are also excluded as they have most likely also been in the background strain, prior to the evolution experiments.

# %%
import pandas as pd
import json

# %%
compounds = ["HMDA", "putrescine", "1,2-propanediol", "2,3-butanediol", "glutarate", "adipate", "hexanoate", "octanoate", "coumarate", "isobutyrate", "butanol"]

mapping = pd.read_csv("../Data/Mutation_data/Variant_calls/mapping.csv", header=None)
compound_mapping = {
    1: "butanol",
    2: "glutarate",
    3: "coumarate",
    5: "HMDA",
    6: "putrescine",
    7: "adipate",
    8: "isobutyrate",
    9: "hexanoate",
    10: "2,3-butanediol",
    11: "1,2-propanediol",
    12: "octanoate"
}
rev_compound_mapping = {v: k for k, v in compound_mapping.items()}

code_to_compound = {
    "BUT": "butanol",
    "GLUT": "glutarate",
    "COUM": "coumarate",
    "HMDA": "HMDA",
    "PUTR": "putrescine",
    "ADIP": "adipate",
    "IBUA": "isobutyrate",
    "HEXA": "hexanoate",
    "23BD": "2,3-butanediol",
    "12PD": "1,2-propanediol",
    "OCTA": "octanoate"
}
comp_to_code = {v: k for k, v in code_to_compound.items()}

# %%
def mut_id(row):
    typ = row["Mutation Type"]
    pos = str(int(row["Position"].replace(",", "")))
    if typ == "SNP":
        last = row["Sequence Change"][-1]
    elif typ == "DEL":
        if "(" in row["Sequence Change"]:
            last = str(len(row["Sequence Change"].split(")")[0][1:]))
        else:
            last = str(int(row["Sequence Change"][1:-3].replace(",", "")))
    elif typ == "INS":
        if "(" in row["Sequence Change"]:
            last = row["Sequence Change"].split(")")[0][1:]
        else:
            last = row["Sequence Change"][1:]
    elif typ == "MOB":
        fields = row["Sequence Change"].split("\xa0")
        last = fields[0] + "-" + fields[2][1:]
    else:
        last = ""
    return "-".join((typ, pos, last))

def strain_code_to_name(strain_code, compound):
    compound_num = rev_compound_mapping[compound]
    fields = strain_code.split(" ")[-4:]
    fields = [f[1:] for f in fields]
    code = (int(fields[0]), int(fields[2]), int(fields[3]))
    strain = mapping[mapping[0] == compound_num].groupby((1, 2, 3)).first().loc[code][4]
    return strain

# %%
strain_to_muts = {}
for comp in compounds:
    df = pd.read_csv("../Data/Mutation_data/Variant_calls/%s.csv" % comp)
    df["mut_id"] = df.apply(mut_id, 1)
    
    for strain_code in df.columns[10:]:
        if strain_code == "mut_id":
            continue
        strain = strain_code_to_name(strain_code, comp)

        muts = list(df[df[strain_code] == 1]["mut_id"])
        strain_to_muts[strain] = set(muts)

# %%
strain_to_muts["GLUT4-4"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-497-18cee919bf38> in <module>()
# ----> 1 strain_to_muts["GLUT4-4"]
#
# KeyError: 'GLUT4-4'

# %%
mapping[mapping[0] == 2]
# Out:
#     0  1  2  3               4
# 20  2  1  1  1         GLUT1-3
# 21  2  1  2  1         GLUT1-9
# 22  2  1  3  1        GLUT1-10
# 23  2  2  1  1         GLUT2-1
# 24  2  2  2  1         GLUT2-9
# 25  2  2  3  1        GLUT2-10
# 26  2  2  3  2  GLUT2-10-rerun
# 27  2  3  1  1         GLUT3-5
# 28  2  3  2  1         GLUT3-7
# 29  2  3  2  2   GLUT3-7-rerun
# 30  2  3  3  1         GLUT3-9
# 31  2  4  1  1         GLUT4-1
# 32  2  4  2  1         GLUT4-4
# 33  2  4  2  2   GLUT4-4-rerun
# 34  2  4  3  1        GLUT4-10
# 35  2  5  1  1         GLUT5-4
# 36  2  5  2  1         GLUT5-5
# 37  2  5  3  1         GLUT5-9
# 38  2  5  3  2   GLUT5-9-rerun
# 39  2  6  1  1         GLUT6-4
# 40  2  6  2  1         GLUT6-5
# 41  2  6  2  2   GLUT6-5-rerun
# 42  2  6  3  1        GLUT6-10
# 43  2  7  1  1         GLUT7-2
# 44  2  7  1  2   GLUT7-2-rerun
# 45  2  7  2  1         GLUT7-6
# 46  2  7  3  1         GLUT7-7
# 47  2  7  3  2   GLUT7-7-rerun
# 48  2  8  1  1         GLUT8-5
# 49  2  8  1  2   GLUT8-5-rerun
# 50  2  8  2  1         GLUT8-6
# 51  2  8  3  1         GLUT8-9

# %%
for comp in code_to_compound:
    print(
        comp,
        len(set.union(*(v for k, v in strain_to_muts.items()  if comp in k))),
        len(set.union(*(v for k, v in old_strain_muts.items() if comp in k)))
    )
# Out:
# HEXA 54 66
# IBUA 161 121
# COUM 245 87
# 12PD 1710 1819
# 23BD 568 502
# BUT 37 69
# OCTA 197 222
# GLUT 103 119
# HMDA 262 266
# ADIP 460 470
# PUTR 84 99

# %%
len(set.union(*strain_to_muts.values()))
# Out:
# 70

# %%
len(set.union(*old_strain_muts.values()))
# Out:
# 119

# %%
len(strain_to_muts)
# Out:
# 224

# %%
len(old_strain_muts)
# Out:
# 224

# %%
for mut in set.union(*strain_to_muts.values()):
    if mut.startswith("DEL"):
        assert int(mut.split("-")[2]) >= 1

# %%
comp = "COUM"
df = pd.read_csv("../Data/Mutation_data/Variant_calls/%s.csv" % code_to_compound[comp])
df["mut_id"] = df.apply(mut_id, 1)

# %%
df[df["Mutation Type"] == "DUP"]
# Out:
#       Position Mutation Type  Sequence Change  \
# 0            0           DUP      575 bp x2.0
# 2        4,261           DUP    2,144 bp x1.9
# 3        7,819           DUP    7,180 bp x1.9
# 4       16,964           DUP    5,102 bp x2.1
# 5       19,520           DUP    1,032 bp x2.7
# 6       19,809           DUP      729 bp x2.9
# 7       27,107           DUP    2,626 bp x1.9
# 8       31,546           DUP   12,593 bp x1.9
# 9       46,951           DUP    4,223 bp x1.8
# 10      53,132           DUP    7,937 bp x1.8
# 11      62,648           DUP    3,516 bp x1.9
# 13      77,050           DUP    1,633 bp x1.9
# 14      83,574           DUP    2,659 bp x2.0
# 15      88,497           DUP    4,583 bp x1.9
# 16      94,620           DUP    2,423 bp x1.9
# 17     102,207           DUP    1,693 bp x2.0
# 19     105,064           DUP    4,101 bp x1.9
# 20     110,453           DUP    4,248 bp x1.8
# 21     116,290           DUP    2,937 bp x1.8
# 22     120,499           DUP    2,925 bp x1.9
# 23     129,193           DUP    3,032 bp x2.0
# 24     135,377           DUP    2,016 bp x1.9
# 25     140,189           DUP   17,471 bp x1.9
# 26     159,797           DUP   12,875 bp x1.9
# 27     177,658           DUP    1,669 bp x1.8
# 28     180,893           DUP    3,408 bp x1.8
# 29     189,468           DUP    9,192 bp x1.9
# 30     199,573           DUP    2,060 bp x1.9
# 31     203,135           DUP    3,088 bp x1.9
# 32     208,131           DUP    3,710 bp x1.8
# ..         ...           ...              ...
# 190  3,392,428           DUP    4,701 bp x2.1
# 191  3,394,946           DUP   19,712 bp x1.8
# 192  3,416,404           DUP    7,803 bp x2.0
# 193  3,431,072           DUP   47,944 bp x1.9
# 197  3,480,240           DUP    8,381 bp x1.7
# 198  3,489,675           DUP   82,036 bp x1.8
# 200  3,572,864           DUP   37,523 bp x1.8
# 201  3,583,459           DUP      725 bp x2.8
# 202  3,583,475           DUP      640 bp x2.4
# 203  3,583,479           DUP      611 bp x2.3
# 204  3,611,452           DUP    5,478 bp x1.7
# 205  3,618,344           DUP   18,272 bp x2.2
# 206  3,637,707           DUP    7,226 bp x1.8
# 207  3,645,851           DUP   24,151 bp x2.4
# 208  3,671,106           DUP   32,513 bp x1.9
# 211  3,704,829           DUP   10,151 bp x1.9
# 212  3,716,033           DUP  114,694 bp x1.9
# 214  3,831,751           DUP   90,880 bp x1.9
# 229  4,549,617           DUP    9,442 bp x1.9
# 230  4,563,138           DUP    3,456 bp x1.8
# 231  4,568,126           DUP    2,095 bp x1.9
# 233  4,572,027           DUP   12,476 bp x1.9
# 234  4,585,735           DUP    2,434 bp x1.9
# 235  4,594,761           DUP    1,475 bp x1.9
# 236  4,597,816           DUP    3,114 bp x1.8
# 237  4,603,099           DUP    5,926 bp x1.9
# 238  4,610,720           DUP    2,116 bp x1.9
# 239  4,615,181           DUP    4,912 bp x1.8
# 240  4,623,802           DUP   10,304 bp x1.9
# 246  4,637,250           DUP    3,675 bp x1.9
#
#                                                   Gene Function Product  \
# 0                                        thrL,  [thrA]      NaN     NaN
# 2                               [thrC],  yaaX,  [yaaA]      NaN     NaN
# 3    [yaaJ],  talB,  mog,  satP,  yaaW,  yaaI,  dna...      NaN     NaN
# 4    nhaA,  nhaR,  insB1,  insA,  rpsT,  yaaY,  [ribF]      NaN     NaN
# 5                                [nhaR],  insB1,  insA      NaN     NaN
# 6                                         insB1,  insA      NaN     NaN
# 7                        [ispH],  rihC,  dapB,  [carA]      NaN     NaN
# 8    [carB],  caiF,  caiE,  caiD,  caiC,  caiB,  ca...      NaN     NaN
# 9                 [yaaU],  kefF,  kefC,  folA,  [apaH]      NaN     NaN
# 10   [pdxA],  surA,  lptD,  djlA,  yabP,  rluA,  [r...      NaN     NaN
# 11                              [rapA],  polB,  [araD]      NaN     NaN
# 13                              [sgrR],  sgrT,  [setA]      NaN     NaN
# 14                                leuL,  leuO,  [ilvI]      NaN     NaN
# 15                 [cra],  mraZ,  rsmH,  ftsL,  [ftsI]      NaN     NaN
# 16                              [murE],  murF,  [mraY]      NaN     NaN
# 17                              [murC],  ddlB,  [ftsQ]      NaN     NaN
# 19                [ftsA],  ftsZ,  lpxC,  secM,  [secA]      NaN     NaN
# 20   [secA],  mutT,  yacG,  zapD,  coaE,  guaC,  [h...      NaN     NaN
# 21                       [hofB],  ppdD,  nadC,  [ampD]      NaN     NaN
# 22                              [aroP],  pdhR,  [aceE]      NaN     NaN
# 23                               [lpd],  yacH,  [acnB]      NaN     NaN
# 24                       [speD],  speE,  yacC,  [cueO]      NaN     NaN
# 25   [gcd],  hpt,  can,  yadG,  yadH,  yadI,  yadE,...      NaN     NaN
# 26   [gluQ],  dksA,  sfsA,  ligT,  hrpB,  mrcB,  fh...      NaN     NaN
# 27                                  btuF,  mtn,  [dgt]      NaN     NaN
# 28                       [degP],  cdaR,  yaeH,  [yaeI]      NaN     NaN
# 29   [map],  rpsB,  tsf,  pyrH,  frr,  dxr,  ispU, ...      NaN     NaN
# 30                               [bamA],  skp,  [lpxD]      NaN     NaN
# 31                       [lpxA],  lpxB,  rnhB,  [dnaE]      NaN     NaN
# 32                                [dnaE],  accA,  ldcC      NaN     NaN
# ..                                                 ...      ...     ...
# 190                                       yhdP,  [rng]      NaN     NaN
# 191  [yhdP],  rng,  yhdE,  mreD,  mreC,  mreB,  csr...      NaN     NaN
# 192          [acrF],  yhdV,  yhdW,  yhdX,  yhdY,  yhdZ      NaN     NaN
# 193  [tsaC],  yrdD,  smg,  smf,  def,  fmt,  rsmB, ...      NaN     NaN
# 197  [kefB],  kefG,  yheS,  yheT,  yheU,  prkB,  yh...      NaN     NaN
# 198  [argD],  pabA,  fic,  yhfG,  ppiA,  tsgA,  nir...      NaN     NaN
# 200  [glgB],  asd,  yhgN,  gntU,  gntK,  gntR,  yhh...      NaN     NaN
# 201                              [yrhA],  insA,  insB1      NaN     NaN
# 202                            [yrhA],  insA,  [insB1]      NaN     NaN
# 203                            [yrhA],  insA,  [insB1]      NaN     NaN
# 204        [yhhS],  yhhT,  acpT,  nikA,  nikB,  [nikC]      NaN     NaN
# 205  [nikE],  nikR,  rhsB,  yhhH,  yrhC,  yhhI,  yh...      NaN     NaN
# 206        [pitA],  uspB,  uspA,  dtpB,  rsmJ,  [prlC]      NaN     NaN
# 207  [rlmJ],  gor,  dinQ,  arsR,  arsB,  arsC,  yhi...      NaN     NaN
# 208  [treF],  yhjB,  yhjC,  yhjD,  yhjE,  yhjG,  yh...      NaN     NaN
# 211  [dppB],  dppA,  eptB,  yhjX,  yhjY,  tag,  yia...      NaN     NaN
# 212  [bisC],  yiaD,  ghrB,  yiaF,  yiaG,  cspA,  mo...      NaN     NaN
# 214  [yicH],  yicI,  yicJ,  yicT,  setC,  yicL,  nl...      NaN     NaN
# 229  [fimH],  gntP,  uxuA,  uxuB,  uxuR,  yjiC,  ir...      NaN     NaN
# 230                      [yjiK],  yjiL,  yjiM,  [yjiN]      NaN     NaN
# 231                             [mdtM],  yjiP,  [yjiR]      NaN     NaN
# 233  yjiT,  yjiV,  mcrC,  mcrB,  symE,  hsdS,  hsdM...      NaN     NaN
# 234                              [hsdR],  mrr,  [yjiA]      NaN     NaN
# 235                                      lgoR,  [lgoD]      NaN     NaN
# 236                             [opgB],  yjjA,  [dnaC]      NaN     NaN
# 237  yjjQ,  bglJ,  fhuF,  yjjZ,  rsmC,  holD,  rimI...      NaN     NaN
# 238                      [prfC],  osmY,  ytjA,  [yjjU]      NaN     NaN
# 239               [yjjW],  yjjI,  deoC,  deoA,  [deoB]      NaN     NaN
# 240  [lplA],  ytjB,  serB,  radA,  nadR,  ettA,  sl...      NaN     NaN
# 246                        [creC],  creD,  arcA,  yjjY      NaN     NaN
#
#     GO Process GO Component Protein change  TOL coumarate A0 F0 I1 R1  \
# 0          NaN          NaN    Duplication                        NaN
# 2          NaN          NaN    Duplication                        NaN
# 3          NaN          NaN    Duplication                        NaN
# 4          NaN          NaN    Duplication                        NaN
# 5          NaN          NaN    Duplication                        NaN
# 6          NaN          NaN    Duplication                        NaN
# 7          NaN          NaN    Duplication                        NaN
# 8          NaN          NaN    Duplication                        NaN
# 9          NaN          NaN    Duplication                        NaN
# 10         NaN          NaN    Duplication                        NaN
# 11         NaN          NaN    Duplication                        NaN
# 13         NaN          NaN    Duplication                        NaN
# 14         NaN          NaN    Duplication                        NaN
# 15         NaN          NaN    Duplication                        NaN
# 16         NaN          NaN    Duplication                        NaN
# 17         NaN          NaN    Duplication                        NaN
# 19         NaN          NaN    Duplication                        NaN
# 20         NaN          NaN    Duplication                        NaN
# 21         NaN          NaN    Duplication                        NaN
# 22         NaN          NaN    Duplication                        NaN
# 23         NaN          NaN    Duplication                        NaN
# 24         NaN          NaN    Duplication                        NaN
# 25         NaN          NaN    Duplication                        NaN
# 26         NaN          NaN    Duplication                        NaN
# 27         NaN          NaN    Duplication                        NaN
# 28         NaN          NaN    Duplication                        NaN
# 29         NaN          NaN    Duplication                        NaN
# 30         NaN          NaN    Duplication                        NaN
# 31         NaN          NaN    Duplication                        NaN
# 32         NaN          NaN    Duplication                        NaN
# ..         ...          ...            ...                        ...
# 190        NaN          NaN    Duplication                        NaN
# 191        NaN          NaN    Duplication                        NaN
# 192        NaN          NaN    Duplication                        NaN
# 193        NaN          NaN    Duplication                        NaN
# 197        NaN          NaN    Duplication                        NaN
# 198        NaN          NaN    Duplication                        NaN
# 200        NaN          NaN    Duplication                        NaN
# 201        NaN          NaN    Duplication                        NaN
# 202        NaN          NaN    Duplication                        NaN
# 203        NaN          NaN    Duplication                        NaN
# 204        NaN          NaN    Duplication                        NaN
# 205        NaN          NaN    Duplication                        NaN
# 206        NaN          NaN    Duplication                        NaN
# 207        NaN          NaN    Duplication                        NaN
# 208        NaN          NaN    Duplication                        NaN
# 211        NaN          NaN    Duplication                        NaN
# 212        NaN          NaN    Duplication                        NaN
# 214        NaN          NaN    Duplication                        NaN
# 229        NaN          NaN    Duplication                        NaN
# 230        NaN          NaN    Duplication                        NaN
# 231        NaN          NaN    Duplication                        NaN
# 233        NaN          NaN    Duplication                        NaN
# 234        NaN          NaN    Duplication                        NaN
# 235        NaN          NaN    Duplication                        NaN
# 236        NaN          NaN    Duplication                        NaN
# 237        NaN          NaN    Duplication                        NaN
# 238        NaN          NaN    Duplication                        NaN
# 239        NaN          NaN    Duplication                        NaN
# 240        NaN          NaN    Duplication                        NaN
# 246        NaN          NaN    Duplication                        NaN
#
#          ...       TOL coumarate A5 F50 I2 R1  TOL coumarate A5 F50 I3 R1  \
# 0        ...                              NaN                         NaN
# 2        ...                              NaN                         NaN
# 3        ...                              NaN                         NaN
# 4        ...                              NaN                         NaN
# 5        ...                              NaN                         NaN
# 6        ...                              NaN                         NaN
# 7        ...                              NaN                         NaN
# 8        ...                              NaN                         NaN
# 9        ...                              NaN                         NaN
# 10       ...                              NaN                         NaN
# 11       ...                              NaN                         NaN
# 13       ...                              NaN                         NaN
# 14       ...                              NaN                         NaN
# 15       ...                              NaN                         NaN
# 16       ...                              NaN                         NaN
# 17       ...                              NaN                         NaN
# 19       ...                              NaN                         NaN
# 20       ...                              NaN                         NaN
# 21       ...                              NaN                         NaN
# 22       ...                              NaN                         NaN
# 23       ...                              NaN                         NaN
# 24       ...                              NaN                         NaN
# 25       ...                              NaN                         NaN
# 26       ...                              NaN                         NaN
# 27       ...                              NaN                         NaN
# 28       ...                              NaN                         NaN
# 29       ...                              NaN                         NaN
# 30       ...                              NaN                         NaN
# 31       ...                              NaN                         NaN
# 32       ...                              NaN                         NaN
# ..       ...                              ...                         ...
# 190      ...                              NaN                         NaN
# 191      ...                              NaN                         NaN
# 192      ...                              NaN                         NaN
# 193      ...                              NaN                         NaN
# 197      ...                              NaN                         NaN
# 198      ...                              NaN                         NaN
# 200      ...                              NaN                         NaN
# 201      ...                              NaN                         NaN
# 202      ...                              NaN                         NaN
# 203      ...                              NaN                         NaN
# 204      ...                              NaN                         NaN
# 205      ...                              NaN                         NaN
# 206      ...                              NaN                         NaN
# 207      ...                              NaN                         NaN
# 208      ...                              NaN                         NaN
# 211      ...                              NaN                         NaN
# 212      ...                              NaN                         NaN
# 214      ...                              NaN                         NaN
# 229      ...                              NaN                         NaN
# 230      ...                              NaN                         NaN
# 231      ...                              NaN                         NaN
# 233      ...                              NaN                         NaN
# 234      ...                              NaN                         NaN
# 235      ...                              NaN                         NaN
# 236      ...                              NaN                         NaN
# 237      ...                              NaN                         NaN
# 238      ...                              NaN                         NaN
# 239      ...                              NaN                         NaN
# 240      ...                              NaN                         NaN
# 246      ...                              NaN                         NaN
#
#      TOL coumarate A6 F50 I1 R1  TOL coumarate A6 F50 I2 R1  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         1.0
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 19                          NaN                         NaN
# 20                          NaN                         NaN
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                          NaN                         NaN
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                          NaN                         NaN
# 30                          NaN                         NaN
# 31                          NaN                         NaN
# 32                          NaN                         NaN
# ..                          ...                         ...
# 190                         1.0                         NaN
# 191                         NaN                         NaN
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         NaN
# 203                         NaN                         NaN
# 204                         NaN                         NaN
# 205                         NaN                         NaN
# 206                         NaN                         NaN
# 207                         NaN                         NaN
# 208                         NaN                         NaN
# 211                         NaN                         NaN
# 212                         NaN                         NaN
# 214                         NaN                         NaN
# 229                         NaN                         NaN
# 230                         NaN                         NaN
# 231                         NaN                         NaN
# 233                         NaN                         NaN
# 234                         NaN                         NaN
# 235                         NaN                         NaN
# 236                         NaN                         NaN
# 237                         NaN                         NaN
# 238                         NaN                         NaN
# 239                         NaN                         NaN
# 240                         NaN                         NaN
# 246                         NaN                         NaN
#
#      TOL coumarate A6 F50 I3 R1  TOL coumarate A7 F50 I1 R1  \
# 0                           1.0                         NaN
# 2                           1.0                         NaN
# 3                           1.0                         NaN
# 4                           1.0                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           1.0                         NaN
# 8                           1.0                         NaN
# 9                           1.0                         NaN
# 10                          1.0                         NaN
# 11                          1.0                         NaN
# 13                          1.0                         NaN
# 14                          1.0                         NaN
# 15                          1.0                         NaN
# 16                          1.0                         NaN
# 17                          1.0                         NaN
# 19                          1.0                         NaN
# 20                          1.0                         NaN
# 21                          1.0                         NaN
# 22                          1.0                         NaN
# 23                          1.0                         NaN
# 24                          1.0                         NaN
# 25                          1.0                         NaN
# 26                          1.0                         NaN
# 27                          1.0                         NaN
# 28                          1.0                         NaN
# 29                          1.0                         NaN
# 30                          1.0                         NaN
# 31                          1.0                         NaN
# 32                          1.0                         NaN
# ..                          ...                         ...
# 190                         NaN                         NaN
# 191                         NaN                         NaN
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         NaN
# 203                         NaN                         1.0
# 204                         NaN                         NaN
# 205                         NaN                         NaN
# 206                         NaN                         NaN
# 207                         NaN                         NaN
# 208                         NaN                         NaN
# 211                         NaN                         NaN
# 212                         NaN                         NaN
# 214                         NaN                         NaN
# 229                         1.0                         NaN
# 230                         1.0                         NaN
# 231                         1.0                         NaN
# 233                         1.0                         NaN
# 234                         1.0                         NaN
# 235                         1.0                         NaN
# 236                         1.0                         NaN
# 237                         1.0                         NaN
# 238                         1.0                         NaN
# 239                         1.0                         NaN
# 240                         1.0                         NaN
# 246                         1.0                         NaN
#
#      TOL coumarate A7 F50 I2 R1  TOL coumarate A8 F50 I1 R1  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 6                           NaN                         NaN
# 7                           NaN                         NaN
# 8                           NaN                         NaN
# 9                           NaN                         NaN
# 10                          NaN                         NaN
# 11                          NaN                         NaN
# 13                          NaN                         NaN
# 14                          NaN                         NaN
# 15                          NaN                         NaN
# 16                          NaN                         NaN
# 17                          NaN                         NaN
# 19                          NaN                         NaN
# 20                          NaN                         NaN
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 23                          NaN                         NaN
# 24                          NaN                         NaN
# 25                          NaN                         NaN
# 26                          NaN                         NaN
# 27                          NaN                         NaN
# 28                          NaN                         NaN
# 29                          NaN                         NaN
# 30                          NaN                         NaN
# 31                          NaN                         NaN
# 32                          NaN                         NaN
# ..                          ...                         ...
# 190                         NaN                         NaN
# 191                         NaN                         NaN
# 192                         NaN                         NaN
# 193                         NaN                         NaN
# 197                         NaN                         NaN
# 198                         NaN                         NaN
# 200                         NaN                         NaN
# 201                         NaN                         NaN
# 202                         NaN                         1.0
# 203                         NaN                         NaN
# 204                         NaN                         NaN
# 205                         NaN                         NaN
# 206                         NaN                         NaN
# 207                         NaN                         NaN
# 208                         NaN                         NaN
# 211                         NaN                         NaN
# 212                         NaN                         NaN
# 214                         NaN                         NaN
# 229                         NaN                         NaN
# 230                         NaN                         NaN
# 231                         NaN                         NaN
# 233                         NaN                         NaN
# 234                         NaN                         NaN
# 235                         NaN                         NaN
# 236                         NaN                         NaN
# 237                         NaN                         NaN
# 238                         NaN                         NaN
# 239                         NaN                         NaN
# 240                         NaN                         NaN
# 246                         NaN                         NaN
#
#      TOL coumarate A8 F50 I2 R1        mut_id
# 0                           NaN        DUP-0-
# 2                           NaN     DUP-4261-
# 3                           NaN     DUP-7819-
# 4                           NaN    DUP-16964-
# 5                           NaN    DUP-19520-
# 6                           NaN    DUP-19809-
# 7                           NaN    DUP-27107-
# 8                           NaN    DUP-31546-
# 9                           NaN    DUP-46951-
# 10                          NaN    DUP-53132-
# 11                          NaN    DUP-62648-
# 13                          NaN    DUP-77050-
# 14                          NaN    DUP-83574-
# 15                          NaN    DUP-88497-
# 16                          NaN    DUP-94620-
# 17                          NaN   DUP-102207-
# 19                          NaN   DUP-105064-
# 20                          NaN   DUP-110453-
# 21                          NaN   DUP-116290-
# 22                          NaN   DUP-120499-
# 23                          NaN   DUP-129193-
# 24                          NaN   DUP-135377-
# 25                          NaN   DUP-140189-
# 26                          NaN   DUP-159797-
# 27                          NaN   DUP-177658-
# 28                          NaN   DUP-180893-
# 29                          NaN   DUP-189468-
# 30                          NaN   DUP-199573-
# 31                          NaN   DUP-203135-
# 32                          NaN   DUP-208131-
# ..                          ...           ...
# 190                         NaN  DUP-3392428-
# 191                         NaN  DUP-3394946-
# 192                         NaN  DUP-3416404-
# 193                         NaN  DUP-3431072-
# 197                         NaN  DUP-3480240-
# 198                         NaN  DUP-3489675-
# 200                         NaN  DUP-3572864-
# 201                         NaN  DUP-3583459-
# 202                         NaN  DUP-3583475-
# 203                         NaN  DUP-3583479-
# 204                         NaN  DUP-3611452-
# 205                         NaN  DUP-3618344-
# 206                         NaN  DUP-3637707-
# 207                         NaN  DUP-3645851-
# 208                         NaN  DUP-3671106-
# 211                         NaN  DUP-3704829-
# 212                         NaN  DUP-3716033-
# 214                         NaN  DUP-3831751-
# 229                         NaN  DUP-4549617-
# 230                         NaN  DUP-4563138-
# 231                         NaN  DUP-4568126-
# 233                         NaN  DUP-4572027-
# 234                         NaN  DUP-4585735-
# 235                         NaN  DUP-4594761-
# 236                         NaN  DUP-4597816-
# 237                         NaN  DUP-4603099-
# 238                         NaN  DUP-4610720-
# 239                         NaN  DUP-4615181-
# 240                         NaN  DUP-4623802-
# 246                         NaN  DUP-4637250-
#
# [190 rows x 31 columns]

# %%
strain_to_muts = {}
for strain_code in df.columns[10:]:
    if strain_code == "mut_id":
        continue
    strain = strain_code_to_name(strain_code, code_to_compound[comp])
    if "rerun" in strain:
        continue
    muts = list(df[df[strain_code] == 1]["mut_id"])
    strain_to_muts[strain] = set(muts)

# %%
def sanitize_mut(mut):
    if mut.startswith("MCDEL"):
        a, b, c = mut.split("-")
        a = "DEL"
        c = str(int(c) - int(b) + 1)
        return "-".join((a, b, c))
    else:
        return mut

# %%
old_strain_muts = {}
with open("../Data/Mutation_data/Strain_mutations_v2.txt") as infile:
    for line in infile:
        strain, *muts = line.strip().split("\t")
        muts = list(map(sanitize_mut, muts))
        old_strain_muts[strain] = set(muts)
common_muts = set.intersection(*old_strain_muts.values())
#for strain in list(old_strain_muts):
#    old_strain_muts[strain] = old_strain_muts[strain] - common_muts
#old_strain_muts = {k: v for k, v in old_strain_muts.items() if k.startswith(comp)}

# %%
set.intersection(*old_strain_muts.values())
# Out:
# {'DEL-1978503-776',
#  'DEL-2173361-2',
#  'DEL-257908-776',
#  'INS-3560455-G',
#  'INS-4296380-CG'}

# %%
def permute_dict(di):
    k = di.keys()
    v = list(di.values())
    random.shuffle(v)
    return dict(zip(k, v))

#strain_to_muts = permute_dict(strain_to_muts)

# %%
for strain1 in list(strain_to_muts):
    for strain2 in list(strain_to_muts):
        if strain1 == strain2:
            print("|", end="")
        # print("%2d" % (100*len(strain_to_muts[strain1] & old_strain_muts[strain2]) / len(strain_to_muts[strain1] | old_strain_muts[strain2])), end=" ")
        # print("%2d" % (len(strain_to_muts[strain1] & old_strain_muts[strain2])), end=" ")
        print("%2d" % (len(strain_to_muts[strain1]) - len(old_strain_muts[strain2])), end=" ")
    print("")
# Out:
# |-8 -4 -3 -8 -7 -8 -5 -5 -3 -4 -5 -5 -4 -4 -5 -6 -7 -6 -6 -8
# -10 |-6 -5 -10 -9 -10 -7 -7 -5 -6 -7 -7 -6 -6 -7 -8 -9 -8 -8 -10
# -8 -4 |-3 -8 -7 -8 -5 -5 -3 -4 -5 -5 -4 -4 -5 -6 -7 -6 -6 -8
# -7 -3 -2 |-7 -6 -7 -4 -4 -2 -3 -4 -4 -3 -3 -4 -5 -6 -5 -5 -7
# 41 45 46 41 |42 41 44 44 46 45 44 44 45 45 44 43 42 43 43 41
# -6 -2 -1 -6 -5 |-6 -3 -3 -1 -2 -3 -3 -2 -2 -3 -4 -5 -4 -4 -6
# -9 -5 -4 -9 -8 -9 |-6 -6 -4 -5 -6 -6 -5 -5 -6 -7 -8 -7 -7 -9
# -8 -4 -3 -8 -7 -8 -5 |-5 -3 -4 -5 -5 -4 -4 -5 -6 -7 -6 -6 -8
# -10 -6 -5 -10 -9 -10 -7 -7 |-5 -6 -7 -7 -6 -6 -7 -8 -9 -8 -8 -10
# -10 -6 -5 -10 -9 -10 -7 -7 -5 |-6 -7 -7 -6 -6 -7 -8 -9 -8 -8 -10
# -10 -6 -5 -10 -9 -10 -7 -7 -5 -6 |-7 -7 -6 -6 -7 -8 -9 -8 -8 -10
# -7 -3 -2 -7 -6 -7 -4 -4 -2 -3 -4 |-4 -3 -3 -4 -5 -6 -5 -5 -7
# -10 -6 -5 -10 -9 -10 -7 -7 -5 -6 -7 -7 |-6 -6 -7 -8 -9 -8 -8 -10
# 120 124 125 120 121 120 123 123 125 124 123 123 124 |124 123 122 121 122 122 120
# -7 -3 -2 -7 -6 -7 -4 -4 -2 -3 -4 -4 -3 -3 |-4 -5 -6 -5 -5 -7
# -8 -4 -3 -8 -7 -8 -5 -5 -3 -4 -5 -5 -4 -4 -5 |-6 -7 -6 -6 -8
# -7 -3 -2 -7 -6 -7 -4 -4 -2 -3 -4 -4 -3 -3 -4 -5 |-6 -5 -5 -7
# -6 -2 -1 -6 -5 -6 -3 -3 -1 -2 -3 -3 -2 -2 -3 -4 -5 |-4 -4 -6
# -9 -5 -4 -9 -8 -9 -6 -6 -4 -5 -6 -6 -5 -5 -6 -7 -8 -7 |-7 -9
# -7 -3 -2 -7 -6 -7 -4 -4 -2 -3 -4 -4 -3 -3 -4 -5 -6 -5 -5 |-7

# %%
strain_to_muts
for strain in strain_to_muts:
    print(strain)
    print("   ", "\n    ".join(sorted(set(strain_to_muts[strain]).intersection(set(old_strain_muts[strain])))))
    print("")
    print("     ", "\n      ".join(sorted(set(strain_to_muts[strain]).difference(set(old_strain_muts[strain])))))
    print("")
    print("     ", "\n      ".join(sorted(set(old_strain_muts[strain]).difference(set(strain_to_muts[strain])))))
# Out:
# COUM3-9
#     DEL-2810080-1165
#     MOB-1293196-IS5-4
#     SNP-1903497-C
#     SNP-3922483-A
#     SNP-3966727-T
#     SNP-4183802-G
#     SNP-663746-T
#
#       DEL-3815810-1
#
#       DEL-1299499-1199
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423705-895
#       DEL-3815809-1
#       DEL-780632-982
#       INS-3560455-G
#       INS-4296380-CG
# COUM5-5
#     MOB-2784452-IS5-4
#     SNP-1352163-A
#     SNP-3966751-T
#     SNP-4185540-T
#     SNP-667158-T
#
#       DEL-4628214-1
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423495-3270
#       DEL-4628212-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM4-2
#     SNP-2141832-T
#     SNP-3440924-G
#     SNP-3473615-T
#     SNP-4375431-C
#     SNP-4627567-T
#
#       DUP-3316547-
#       DUP-3361691-
#       DUP-3367122-
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423726-828
#       INS-3560455-G
#       INS-4296380-CG
# COUM5-8
#     MOB-2784452-IS5-4
#     SNP-1352163-A
#     SNP-1768309-T
#     SNP-3966751-T
#     SNP-4185540-T
#     SNP-667158-T
#     SNP-954638-T
#
#       DEL-3471319-1
#       INS-3922570-TAG
#
#       DEL-1299499-1199
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423722-867
#       DEL-3471315-1
#       INS-3560455-G
#       INS-3922565-AGT
#       INS-4296380-CG
# COUM6-9
#     DEL-1299499-1199
#     MOB-1347892-IS5-4
#     SNP-1903497-C
#     SNP-3317438-A
#     SNP-3530902-G
#     SNP-3966727-T
#     SNP-4569172-A
#
#       DEL-3815810-1
#       DUP-0-
#       DUP-102207-
#       DUP-105064-
#       DUP-110453-
#       DUP-116290-
#       DUP-120499-
#       DUP-129193-
#       DUP-135377-
#       DUP-140189-
#       DUP-159797-
#       DUP-16964-
#       DUP-177658-
#       DUP-180893-
#       DUP-189468-
#       DUP-199573-
#       DUP-203135-
#       DUP-208131-
#       DUP-212751-
#       DUP-215329-
#       DUP-230568-
#       DUP-243065-
#       DUP-251719-
#       DUP-255468-
#       DUP-266456-
#       DUP-27107-
#       DUP-31546-
#       DUP-3382679-
#       DUP-4261-
#       DUP-4549617-
#       DUP-4563138-
#       DUP-4568126-
#       DUP-4572027-
#       DUP-4585735-
#       DUP-4594761-
#       DUP-4597816-
#       DUP-4603099-
#       DUP-4610720-
#       DUP-4615181-
#       DUP-4623802-
#       DUP-4637250-
#       DUP-46951-
#       DUP-53132-
#       DUP-62648-
#       DUP-77050-
#       DUP-7819-
#       DUP-83574-
#       DUP-88497-
#       DUP-94620-
#       MOB-4544671-+G-S5
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423723-867
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG
#       MOB-4544671-IS5-3
# COUM2-4
#     DEL-1299499-1199
#     DEL-4627451-124
#     MOB-1961829-IS5-4
#     MOB-2297586-IS5-4
#     MOB-3922629-IS5-4
#     SNP-1352163-A
#     SNP-3966751-T
#     SNP-4099695-A
#     SNP-4185540-T
#
#       DEL-102228-1
#
#       DEL-102227-1
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423751-816
#       INS-3560455-G
#       INS-4296380-CG
# COUM4-5
#     SNP-1436746-C
#     SNP-2141832-T
#     SNP-2743181-G
#     SNP-3440924-G
#     SNP-3473615-T
#     SNP-4627567-T
#
#       DUP-3316547-
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423763-777
#       DEL-4392433-161
#       INS-3560455-G
#       INS-4296380-CG
# COUM1-2
#     SNP-1168483-T
#     SNP-1354284-A
#     SNP-3966727-T
#     SNP-4185540-T
#     SNP-4627958-T
#     SNP-64352-C
#
#       DEL-1299499-1199
#       DEL-4546637-1
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423735-841
#       DEL-4546635-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM8-6
#     DEL-1299499-1199
#     DEL-2801966-11843
#     DEL-3685181-273
#
#       DEL-3815810-1
#       INS-3966718-GAT
#       SNP-1903497-C
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423759-796
#       DEL-3815809-1
#       INS-3560455-G
#       INS-3966715-GAT
#       INS-4296380-CG
# COUM4-10
#     SNP-2141832-T
#     SNP-3440924-G
#     SNP-3473615-T
#     SNP-4627567-T
#
#       DUP-3316547-
#       DUP-3583459-
#
#       DEL-1209603-16
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423755-794
#       DEL-4392434-155
#       INS-3560455-G
#       INS-4296380-CG
# COUM2-7
#     DEL-4627451-124
#     MOB-3922629-IS5-4
#     SNP-1352163-A
#     SNP-3966751-T
#     SNP-4185540-T
#
#       DEL-102228-1
#
#       DEL-102227-1
#       DEL-1299499-1199
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423486-1074
#       INS-3560455-G
#       INS-4296380-CG
# COUM6-2
#     MOB-1347892-IS5-4
#     SNP-1903497-C
#     SNP-3317438-A
#     SNP-3530902-G
#     SNP-3966727-T
#     SNP-4569172-A
#
#       DEL-3815810-1
#       DUP-3382962-
#       DUP-3392428-
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423713-868
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM8-1
#     DEL-2801966-11843
#     SNP-1903497-C
#     SNP-2374-T
#
#       DEL-3683736-1
#       DEL-3815810-1
#       DUP-3583475-
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423746-834
#       DEL-3683735-1
#       DEL-3815809-1
#       INS-3560455-G
#       INS-3966715-GAT
#       INS-4296380-CG
# COUM2-3
#     DEL-4627451-124
#     MOB-3922629-IS5-4
#     SNP-1352163-A
#     SNP-3966751-T
#     SNP-4185540-T
#
#       DEL-102228-1
#       DUP-19809-
#       DUP-2153522-
#       DUP-2203757-
#       DUP-2230567-
#       DUP-2248846-
#       DUP-2277221-
#       DUP-2283904-
#       DUP-2302677-
#       DUP-2315725-
#       DUP-2349564-
#       DUP-2364669-
#       DUP-2380840-
#       DUP-2388349-
#       DUP-2412283-
#       DUP-2423083-
#       DUP-2449738-
#       DUP-2455198-
#       DUP-2468962-
#       DUP-2482796-
#       DUP-2511325-
#       DUP-2517129-
#       DUP-2522064-
#       DUP-2526701-
#       DUP-2531397-
#       DUP-2536626-
#       DUP-2543740-
#       DUP-2546395-
#       DUP-2551832-
#       DUP-2558674-
#       DUP-2561394-
#       DUP-2580826-
#       DUP-2598979-
#       DUP-2603627-
#       DUP-2615290-
#       DUP-2619810-
#       DUP-2623513-
#       DUP-2629215-
#       DUP-2658050-
#       DUP-2683036-
#       DUP-2687027-
#       DUP-2702536-
#       DUP-2706923-
#       DUP-2732699-
#       DUP-2743383-
#       DUP-2750516-
#       DUP-2756345-
#       DUP-2768430-
#       DUP-2789482-
#       DUP-2793906-
#       DUP-2803748-
#       DUP-2808757-
#       DUP-2814624-
#       DUP-2826891-
#       DUP-2832388-
#       DUP-2838052-
#       DUP-2848873-
#       DUP-2855165-
#       DUP-2859624-
#       DUP-2864146-
#       DUP-2867424-
#       DUP-2876021-
#       DUP-2881210-
#       DUP-2890676-
#       DUP-2896491-
#       DUP-2912598-
#       DUP-2919104-
#       DUP-2932941-
#       DUP-2937736-
#       DUP-2941208-
#       DUP-2944187-
#       DUP-2948243-
#       DUP-2961117-
#       DUP-2975361-
#       DUP-2980085-
#       DUP-2983852-
#       DUP-2997830-
#       DUP-3002553-
#       DUP-3011138-
#       DUP-3013986-
#       DUP-3019113-
#       DUP-3027016-
#       DUP-3031003-
#       DUP-3046402-
#       DUP-3050744-
#       DUP-3054279-
#       DUP-3058117-
#       DUP-3064173-
#       DUP-3068090-
#       DUP-3083804-
#       DUP-3093266-
#       DUP-3103123-
#       DUP-3112084-
#       DUP-3114733-
#       DUP-3122685-
#       DUP-3131452-
#       DUP-3139506-
#       DUP-3145875-
#       DUP-3154333-
#       DUP-3161987-
#       DUP-3165864-
#       DUP-3175240-
#       DUP-3183317-
#       DUP-3187500-
#       DUP-3196669-
#       DUP-3215199-
#       DUP-3219652-
#       DUP-3225616-
#       DUP-3239591-
#       DUP-3251806-
#       DUP-3260966-
#       DUP-3276753-
#       DUP-3305369-
#       DUP-3310328-
#       DUP-3345765-
#       DUP-3367171-
#       DUP-3383609-
#       DUP-3394946-
#       DUP-3416404-
#       DUP-3431072-
#       DUP-3480240-
#       DUP-3489675-
#       DUP-3572864-
#       DUP-3611452-
#       DUP-3618344-
#       DUP-3637707-
#       DUP-3645851-
#       DUP-3671106-
#       DUP-3704829-
#       DUP-3716033-
#       DUP-3831751-
#
#       DEL-102227-1
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423776-759
#       INS-3560455-G
#       INS-4296380-CG
# COUM6-5
#     MOB-1347892-IS5-4
#     SNP-1903497-C
#     SNP-3317438-A
#     SNP-3530902-G
#     SNP-3966727-T
#     SNP-4569172-A
#
#       DEL-3815810-1
#       DUP-19520-
#       DUP-3383127-
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423753-809
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM3-10
#     DEL-2810080-1165
#     MOB-1293196-IS5-4
#     SNP-1903497-C
#     SNP-3922483-A
#     SNP-3966727-T
#     SNP-4183802-G
#     SNP-663746-T
#
#       DEL-3815810-1
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423708-893
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM5-3
#     DEL-4054531-104
#     DEL-4628232-1
#     MOB-2678755-IS5-4
#     MOB-2784452-IS5-4
#     MOB-3922629-IS5-4
#     SNP-1352163-A
#     SNP-3966751-T
#     SNP-4185540-T
#     SNP-667158-T
#
#
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423710-863
#       INS-3560455-G
#       INS-4296380-CG
# COUM7-5
#     DEL-1299499-1199
#     DEL-2810804-1
#     MOB-1856052-IS5-4
#     MOB-2782626-IS5-4
#     SNP-1903497-C
#     SNP-3966727-T
#
#       DEL-3815810-1
#       DUP-3583479-
#       INS-3277273-TTCAACA
#       SNP-4183814-A
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423703-871
#       DEL-3815809-1
#       INS-3277257-CATTCAA
#       INS-3560455-G
#       INS-4296380-CG
# COUM7-6
#     DEL-2810804-1
#     MOB-1908812-IS5-4
#     MOB-2782626-IS5-4
#     SNP-1903497-C
#     SNP-3966727-T
#     SNP-4183814-A
#
#       DEL-3815810-1
#
#       DEL-1299499-1199
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-3423727-855
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG
# COUM3-1
#     DEL-260217-13738
#     DEL-2810080-1165
#     MOB-1293196-IS5-4
#     SNP-1903497-C
#     SNP-3922483-A
#     SNP-3966727-T
#     SNP-4183802-G
#     SNP-663746-T
#
#       DEL-3815810-1
#
#       DEL-1978503-776
#       DEL-2173361-2
#       DEL-257908-776
#       DEL-260217-14848
#       DEL-3423726-842
#       DEL-3815809-1
#       INS-3560455-G
#       INS-4296380-CG

# %%
df["mut_id"]
# Out:
# 0         SNP-7618-G
# 1        SNP-11664-C
# 2         DUP-19817-
# 3         DUP-19821-
# 4         DUP-19836-
# 5         DUP-19838-
# 6         DUP-19839-
# 7        SNP-52332-C
# 8        SNP-67483-T
# 9        SNP-82372-C
# 10       SNP-83066-C
# 11      SNP-111300-C
# 12      SNP-112052-G
# 13      SNP-146566-A
# 14      SNP-156869-G
# 15      SNP-206330-G
# 16      SNP-257250-C
# 17      SNP-301521-C
# 18      SNP-358399-G
# 19      DEL-367852-2
# 20      INS-380022-G
# 21      SNP-403627-G
# 22      SNP-430137-G
# 23      SNP-436419-C
# 24      SNP-457616-G
# 25      SNP-473636-G
# 26      SNP-511572-C
# 27      DEL-569541-1
# 28      SNP-587023-C
# 29      SNP-622725-C
#            ...
# 232    SNP-4128549-C
# 233    SNP-4133696-C
# 234    SNP-4143217-C
# 235    SNP-4181706-T
# 236    SNP-4181786-T
# 237    SNP-4185708-C
# 238    SNP-4188767-T
# 239    SNP-4256722-C
# 240    SNP-4257602-T
# 241    SNP-4272717-C
# 242    SNP-4290993-C
# 243    SNP-4304847-G
# 244    SNP-4321045-C
# 245    SNP-4369961-C
# 246    SNP-4372620-C
# 247    SNP-4378331-G
# 248    DEL-4410053-1
# 249    SNP-4410605-T
# 250    SNP-4416967-G
# 251    DEL-4457113-4
# 252    SNP-4469328-G
# 253    SNP-4485639-C
# 254    SNP-4494164-G
# 255    SNP-4494308-G
# 256    SNP-4509433-C
# 257    SNP-4549509-A
# 258    SNP-4623272-C
# 259    SNP-4626686-C
# 260    SNP-4628246-C
# 261    SNP-4636416-G
# Name: mut_id, dtype: object

# %%
df.columns
# Out:
# Index(['Position', 'Mutation Type', 'Sequence Change', 'Gene', 'Function',
#        'Product', 'GO Process', 'GO Component', 'Protein change',
#        'TOL 20C nbutanol A0 F0 I1 R1', 'TOL 20C nbutanol A1 F50 I1 R1',
#        'TOL 20C nbutanol A1 F50 I2 R1', 'TOL 20C nbutanol A1 F50 I3 R1',
#        'TOL 20C nbutanol A2 F50 I1 R1', 'TOL 20C nbutanol A3 F50 I1 R1',
#        'TOL 20C nbutanol A3 F50 I2 R1', 'TOL 20C nbutanol A3 F50 I3 R1',
#        'TOL 20C nbutanol A4 F50 I1 R1', 'TOL 20C nbutanol A4 F50 I2 R1',
#        'TOL 20C nbutanol A4 F50 I3 R1', 'TOL 20C nbutanol A5 F50 I1 R1',
#        'TOL 20C nbutanol A5 F50 I2 R1', 'TOL 20C nbutanol A6 F50 I1 R1',
#        'TOL 20C nbutanol A6 F50 I2 R1', 'TOL 20C nbutanol A6 F50 I3 R1',
#        'TOL 20C nbutanol A7 F50 I1 R1', 'TOL 20C nbutanol A7 F50 I2 R1',
#        'TOL 20C nbutanol A7 F50 I3 R1', 'TOL 20C nbutanol A8 F50 I1 R1',
#        'TOL 20C nbutanol A8 F50 I2 R1'],
#       dtype='object')

# %%
mapping[mapping[0] == 1]
# Out:
#     0  1  2  3        4
# 0   1  1  1  1   BUT1-2
# 1   1  1  2  1   BUT1-3
# 2   1  1  3  1   BUT1-5
# 3   1  2  1  1   BUT2-9
# 4   1  3  1  1   BUT3-3
# 5   1  3  2  1   BUT3-6
# 6   1  3  3  1   BUT3-7
# 7   1  4  1  1   BUT4-4
# 8   1  4  2  1   BUT4-7
# 9   1  4  3  1   BUT4-9
# 10  1  5  1  1   BUT5-2
# 11  1  5  2  1   BUT5-3
# 12  1  6  1  1   BUT6-1
# 13  1  6  2  1   BUT6-3
# 14  1  6  3  1   BUT6-8
# 15  1  7  1  1   BUT7-6
# 16  1  7  2  1   BUT7-7
# 17  1  7  3  1   BUT7-9
# 18  1  8  1  1   BUT9-7
# 19  1  8  2  1  BUT9-10

# %%
len(mapping[4])
# Out:
# 233

# %%
breseq_file = "../Data/Mutation_data/Strain_mutations_v1.txt"

# Read the breseq file into a {strain: set(mutations)} dictionary.
strains = {}
with open(breseq_file) as infile:
    for line in infile:
        strain, *mutations = line.strip().split("\t")
        strains[strain] = set(mutations)
        

print(len(strains), "strains with a total of", len(set.union(*strains.values())), "mutations")
# Out:
# 242 strains with a total of 5991 mutations

# %%
common_mutations = set()
mutation_counts = pd.DataFrame(
    {s: {m: 1 for m in muts} for s, muts in strains.items()}
).fillna(0).sum(1).astype("int").sort_values(ascending=False)
for mut, count in mutation_counts.items():
    if count > 230:
        common_mutations.add(mut)
print(len(common_mutations), "mutations are present in more than 230 strains")
print(
    "The most common of the remaining mutations is present in",
    mutation_counts[~mutation_counts.index.isin(common_mutations)].max()
)

# Remove common mutations from strain genotypes
strains = {strain: muts - common_mutations for strain, muts in strains.items()}

# Exclude "DEL-1299499-1199" as this seemed like an erroneous call
strains = {strain: muts - {"DEL-1299499-1199"} for strain, muts in strains.items()}
# Out:
# 7 mutations are present in more than 230 strains
# The most common of the remaining mutations is present in 67

# %%
# The strain 12PD6-9 had many low-coverage regions most likely due to sequencing issues.
# These missing-coverage calls are removed
strains["12PD6-9"] = frozenset(mut for mut in strains["12PD6-9"] if not mut.startswith("MCDEL"))

# %%
# Save file
with open("../Data/Mutation_data/All_strains_to_mutations.json", "w") as outfile:
    json.dump({k: list(v) for k, v in strains.items()}, outfile)

# %%
# Load mapping of mutations to affected genes.
# Mutations are mapped to any genes whose CDS contain the mutation.
# Intergenic mutations are mapped to the closest neighbor gene which the mutation is upstream of.
with open("../Data/Mutation_data/Mutations_to_gene_names.json") as infile:
    mutations_to_gene_names = {mut: set(genes) for mut, genes in json.load(infile).items()}

# %%
# A {strain: mutated_genes} dictionary is constructed

strain_to_gene_names = {strain: set.union(*(mutations_to_gene_names[mut] for mut in muts)) for strain, muts in strains.items()}

# Count how many strains have mutations in each gene
gene_counts = pd.DataFrame({s: {m: 1 for m in muts} for s, muts in strain_to_gene_names.items()}).fillna(0).sum(1).astype("int").sort_values(ascending=False)

# Find genes that are mutated in (almost) all strains, meaning it was most likely mutated in the background strain
common_gene_mutations = set(gene_counts[gene_counts > 240].index)


# Remove genes that are mutated in all strains
strain_to_gene_names = {strain: genes - common_gene_mutations for strain, genes in strain_to_gene_names.items()}
print(len(set.union(*strain_to_gene_names.values())), "total genes are mutated")
print("Most commonly mutated gene is mutated in", gene_counts[~gene_counts.index.isin(common_gene_mutations)].max(), "strains")

with open("../Data/Mutation_data/All_strains_to_gene_names.json", "w") as outfile:
    json.dump({strain: list(genes) for strain, genes in strain_to_gene_names.items()}, outfile)
# Out:
# 2811 total genes are mutated
# Most commonly mutated gene is mutated in 88 strains

# %%
# Find strains that have mutations in mutX genes
hypermutators = []
for strain, gens in strain_to_gene_names.items():
    for gen in gens:
        if gen.startswith("mut"):
            #print(strain, gen)
            hypermutators.append(strain)
hypermutators = set(hypermutators)
non_hyper_mutators = set(strains) - hypermutators
print(len(non_hyper_mutators), "strains are not hypermutators.")
# Out:
# 190 strains are not hypermutators.

# %%
# Save data
with open("../Data/Mutation_data/Strain_to_genes.json", "w") as outfile:
    json.dump({strain: list(strain_to_gene_names[strain]) for strain in non_hyper_mutators}, outfile)

# %%
# This should be moved to the mutation histogram plot notebook

def overlaps(start1, end1, start2, end2):
    """Function to check whether two mutations overlap"""
    if start1 <= end2 and start2 <= end1:
        return True
    else:
        return False
    
# Remove any MCDEL calls that overlap with a DEL call
mcdels_to_remove = {}  # Remove duplicate MCDEL / DEL calls
for strain, muts in strains.items():
    dels = { # mut: (start, end) #
        mut: (int(mut.split("-")[1]), int(mut.split("-")[1])+int(mut.split("-")[2]))
        for mut in muts if mut.startswith("DEL")
    }
    mcdels = {
        mut: (int(mut.split("-")[1]), int(mut.split("-")[2]))
        for mut in muts if mut.startswith("MCDEL")
    }
    remove_list = []
    for mcdel, (start1, end1) in mcdels.items():
        for del_id, (start2, end2) in dels.items():
            if overlaps(start1, end1, start2, end2):
                remove_list.append(mcdel)
                break
    mcdels_to_remove[strain] = set(remove_list)

strains = {strain: muts - mcdels_to_remove[strain] for strain, muts in strains.items()}
print("Removing", len(set.union(*mcdels_to_remove.values())), "MCDEL mutations")
print(len(set.union(*strains.values())), "unique mutations")
